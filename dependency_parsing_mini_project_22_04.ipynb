# %% [markdown]
# <a href="https://colab.research.google.com/github/rafzur1-commits/pythonstuff/blob/main/dependency_parsing_mini_project_22_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mini Project 1: Dependency Parsing and spaCy Feature Analysis from a CSV File
#
# In the previous notebook, we worked with **Treebank** sentences.
# In this notebook, we move to a **real dataset stored in CSV format**.
#
# We will use a news dataset in which the text is stored in columns such as `title` and `text`.
#
# Your job in class is to:
#
# 1. load a CSV file with `pandas`,
# 2. inspect the available columns,
# 3. choose **one text column**,
# 4. clean the data minimally,
# 5. explore the data,
# 6. run **dependency parsing** on selected examples,
# 7. start **Mini Project 1**.
#
# For the mini project, you will choose **one spaCy feature** and write a short analysis in markdown.
#
# We are using this dataset: https://www.kaggle.com/datasets/clmentbisaillon/fake-and-real-news-dataset

# %% [markdown]
# ## Dataset for this class
#
# Use the Kaggle dataset **Fake and Real News Dataset** by `clmentbisaillon`.
#
# According to the dataset description, it contains **two CSV files** (`Fake.csv` and `True.csv`) and the article fields include **title, text, subject, and date**.
#
# For class, you may use **either one file** (`Fake.csv` or `True.csv`) or combine both later if needed.

# %% [markdown]
# ## Recommended workflow
#
# Keep the process simple:
#
# - first, inspect the CSV,
# - then choose a text column,
# - then clean it minimally,
# - then test dependency parsing on a few rows,
# - then begin the project analysis.
#
# Do not try to build a full machine learning system.
# This notebook is for **linguistic exploration**.

# %%
# !pip install -q spacy pandas
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 89.5 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import pandas as pd
import spacy
from spacy import displacy

nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# ## Step 1. Upload your CSV file
#
# Upload **one** CSV file from the dataset, for example:
#
# - `Fake.csv`
# - `True.csv`
#
# You can work with one file first.
# Later, if you want, you may compare the two files.

# %%
import pandas as pd

df = pd.read_csv("/content/Fake.csv") # reads the csv
display(df.head()) #
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %% [markdown]
# ## Step 2. Read the file with pandas
#
# Replace the file name below with the name of the file you uploaded.

# %%
filename = "Fake.csv"   # change this if needed

df = pd.read_csv(filename)
df.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
df.columns # Minimally cleaning the title column
text_col = df['title']
print(text_col)
df = df.dropna()
df = df.drop_duplicates()
df['title'] = df['title'].str.strip().str.lower()
# Out:
# 0         Donald Trump Sends Out Embarrassing New Year’...
# 1         Drunk Bragging Trump Staffer Started Russian ...
# 2         Sheriff David Clarke Becomes An Internet Joke...
# 3         Trump Is So Obsessed He Even Has Obama’s Name...
# 4         Pope Francis Just Called Out Donald Trump Dur...
#                                ...
# 23476    McPain: John McCain Furious That Iran Treated ...
# 23477    JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478    Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479    How to Blow $700 Million: Al Jazeera America F...
# 23480    10 U.S. Navy Sailors Held by Iranian Military ...
# Name: title, Length: 23478, dtype: object

# %%
df['title'].head(4) #exploring the data, ig
df["length"] = df["title"].str.len()
df["length"].describe()
df['subject'].value_counts()
# Out:
# subject
# News               9050
# politics           6838
# left-news          4459
# Government News    1570
# US_News             783
# Middle-east         778
# Name: count, dtype: int64

# %%
sample_text = df['text'].iloc[0] #dependency parsing with displacy
doc = nlp(sample_text[:84])
displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="de8dbc3be5014231b49bb7762e32542d-0" class="displacy" width="3025" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Donald</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Trump</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
# ...

# %% [markdown]
# # Mini Project 1
#
# ## Goal
#
# Use a CSV text dataset and spaCy to produce a short, notebook-based linguistic analysis.
#
# Your notebook should include:
#
# 1. **data loading**
# 2. **minimal cleaning**
# 3. **exploratory analysis**
# 4. **one chosen spaCy feature**
# 5. **examples from the data**
# 6. **one short written summary in markdown**

# %% [markdown]
# ## Project instructions
#
# Choose **one** linguistic feature from spaCy.
#
#
# You do **not** need to use dependency parsing for every possible part of the project.
# But you should include **at least one dependency-based component**.

# %% [markdown]
# ## Minimum project requirements
#
# Your project should contain:
#
# ### 1. Data cleaning
# Show the cleaning steps you applied.
#
# ### 2. Exploratory analysis
# Include at least **two simple observations**, for example:
# - number of rows,
# - average text length,
# - shortest / longest texts,
# - number of sentences in a sample.
#
# ### 3. Feature choice
# State which spaCy feature you selected.
#
# ### 4. Analysis
# Write code that extracts or counts this feature.
#
# ### 5. Examples
# Show at least **10 examples** from the dataset.
#
# ### 6. Summary
# Write a short markdown section explaining what you found.

# %% [markdown]
# ## Suggested structure for your markdown summary
#
# Use short sections such as:
#
# - **Dataset**
# - **Cleaning**
# - **Exploratory analysis**
# - **Feature selected**
# - **Findings**
# - **Limitations**

# %%
# Exploratory analysis idea 1:
# Add your own code here.
# Example questions:
# - How many rows are in the cleaned dataset?
# - What is the average number of characters per text?
# - What is the average number of sentences per text in the sample?

# %%
# Exploratory analysis idea 2:
# Add your own code here.
# You may want to compare:
# - short vs long texts
# - title vs text

# %%
# Feature analysis:
# Choose ONE spaCy feature and start below.

results = []

# Add your own code here.
# You may want to loop through:
# - rows in the dataframe
# - parsed documents
# - tokens in each document

# %%
# Show examples from your analysis
# Print or display at least 10 examples.

# %%
# Dependency parsing requirement:
# Choose one sentence from one text and visualize it with displaCy.

# Add your code here.

# %% [markdown]
# ## Final markdown task
#
# Write a short summary of your findings in a markdown cell.
#
# Keep it brief but specific:
#
# - What did you analyze?
# - What did you find?
# - What pattern did you notice?
# - What are the limits of your analysis?

# %% [markdown]
# ## Optional extension
#
# If you finish early, you may try one of the following:
#
# - compare `title` and `text`
# - compare `Fake.csv` and `True.csv`
# - compare two different spaCy features
# - compare two different sentence visualizations
